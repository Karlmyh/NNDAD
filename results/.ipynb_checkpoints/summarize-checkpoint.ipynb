# %%
import os
import numpy as np 
import pandas as pd
import glob


log_file_dir = "./simulation"
method_seq = glob.glob("{}/*.csv".format(log_file_dir))

method_seq = [os.path.split(method)[1].split('.')[0] for method in method_seq]

print(method_seq)

summarize_log=pd.DataFrame([])

for method in method_seq:
    
    log = pd.read_csv("{}/{}.csv".format(log_file_dir,method), header=None)
    
    
    log.columns = "model,iteration,dim,n,ratio,trainingtime,testtime,roc_auc,mae,n_estimators,lamda".split(',')
    log["method"]=method
    summarize_log=summarize_log.append(log)
# Out:
# ['NNDAD-B', 'NNDAD-S']

# %%
filter_columns = ["method", "dim", "ratio", "n", "n_estimators", "lamda"]
unique_values_dict = {col: summarize_log[col].unique().tolist() for col in filter_columns}
unique_values_dict

values_to_filter = {
    "method": ['NNDAD-B', 'NNDAD-S'],
    "dim": [1],
    "ratio": [0.1],
    'n': [1000, 6000, 11000, 16000, 21000, 26000],
}
mask_list = [summarize_log[col].isin(values) for col, values in values_to_filter.items()]
combined_mask = mask_list[0]
for mask in mask_list[1:]:
    combined_mask = combined_mask & mask
filtered_log = summarize_log[combined_mask]

# %%
mean_df = filtered_log.groupby(by=["method", "dim", "ratio", "n", "n_estimators"]).agg('mean').reset_index()
mean_df
# Out:
#     method  dim  ratio     n  n_estimators  iteration  trainingtime  testtime  \
# 0  NNDAD-B    1    0.1  1000             1        0.0      0.515686  0.125834
# 1  NNDAD-B    1    0.1  1000             5        0.0      0.391342  0.084012
# 2  NNDAD-B    1    0.1  1000            10        0.0      0.311099  0.083780
# 3  NNDAD-S    1    0.1  1000             1        0.0      0.138491  0.136087
# 4  NNDAD-S    1    0.1  1000             5        0.0      0.014770  0.059676
# 5  NNDAD-S    1    0.1  1000            10        0.0      0.018189  0.049695
#
#     roc_auc       mae  lamda
# 0  0.995172  0.866406    1.0
# 1  0.993686  0.834169    1.0
# 2  0.991917  0.829434    1.0
# 3  0.992589  0.807882    1.9
# 4  0.992711  0.796752    1.9
# 5  0.991011  0.809398    1.9
